# %% [markdown]
# # Classifier training
#
# **Inputs:**
# - data/heart_disease_cleaned.csv
# - data/fair_heart_disease.csv
# - data/counterfactual_heart_disease.csv
#
# **Outputs:**
# - results/perf_metrics.csv
